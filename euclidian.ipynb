# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('sample1.jpg')

# Define the rotation angle
angle = 45  # in degrees
tx, ty = 50, 30  # Translation values

# Compute the Euclidean transformation matrix
rotation_matrix = cv2.getRotationMatrix2D((image.shape[1]//2, image.shape[0]//2), angle, 1)

# Adjust for translation
rotation_matrix[0, 2] += tx
rotation_matrix[1, 2] += ty

# Apply the Euclidean transformation
euclidean_result = cv2.warpAffine(image, rotation_matrix, (image.shape[1], image.shape[0]))

# Display the result
plt.imshow(euclidean_result)
plt.title("Euclidean Transformation")
plt.axis("off")
plt.show()
