# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('sample1.jpg')

# Define the scaling factor and rotation angle
scaling_factor = 1.5
angle = 30  # in degrees
tx, ty = 100, 50  # Translation values

# Compute the similarity transformation matrix
rotation_matrix = cv2.getRotationMatrix2D((image.shape[1]//2, image.shape[0]//2), angle, scaling_factor)

# Adjust for translation
rotation_matrix[0, 2] += tx
rotation_matrix[1, 2] += ty

# Apply the similarity transformation
similarity_result = cv2.warpAffine(image, rotation_matrix, (image.shape[1], image.shape[0]))

# Display the result
plt.imshow(similarity_result)
plt.title("similarity Transformation")
plt.axis("off")
plt.show()
