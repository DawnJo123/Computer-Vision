# %%
import cv2
from skimage.feature import hog
from skimage import color, io

# Load image
img = io.imread('001.jpg')
gray = color.rgb2gray(img)

# Compute HOG
fd, hog_image = hog(gray, orientations=5, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True)

# Show results
# cv2.imshow('HOG Features', hog_image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
print(fd)
# Out:
# [0.14369077 0.23031927 0.34878519 ... 0.28437795 0.04648308 0.1602046 ]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(gray, cmap='gray')

# Show HOG image
plt.subplot(1, 2, 2)
plt.title('HOG Features')
plt.imshow(hog_image, cmap='gray')
